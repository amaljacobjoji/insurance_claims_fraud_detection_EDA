# %% [markdown]
# # INTRODUCTION TO EXPLORATORY DATA ANALYSIS

# %% [markdown]
# Exploratory Data Analysis, often abbreviated as EDA, is a crucial first step in any data analysis project. It's like being a detective investigating a new case - you examine the evidence (data) carefully, trying to understand its main characteristics, identify patterns, and uncover interesting relationships.

# %% [markdown]
# ## DATASET - INSURANCE CLAIM FRAUD ANALYSIS

# %% [markdown]
# IMPORTING DATA

# %%
import pandas as pd
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r'C:\Users\amalj\Downloads\insurance_claims.csv')

# %%
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#      policy_annual_premium insured_sex insured_occupation incident_date  \
# ...

# %% [markdown]
# ## LOAD DESCRIBE

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_annual_premium  \
# count         1000.000000  1000.000000    1000.000000            1000.000000
# mean           203.954000    38.948000  546238.648000            1256.406150
# std            115.113174     9.140287  257063.005276             244.167395
# min              0.000000    19.000000  100804.000000             433.330000
# 25%            115.750000    32.000000  335980.250000            1089.607500
# 50%            199.500000    38.000000  533135.000000            1257.200000
# 75%            276.250000    44.000000  759099.750000            1415.695000
# max            479.000000    64.000000  999435.000000            2047.590000
#
#        incident_hour_of_the_day  number_of_vehicles_involved    witnesses  \
# count               1000.000000                   1000.00000  1000.000000
# mean                  11.644000                      1.83900     1.487000
# ...

# %% [markdown]
# ## LOAD INFO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_annual_premium        1000 non-null   float64
#  6   insured_sex                  1000 non-null   object
#  7   insured_occupation           1000 non-null   object
#  8   incident_date                1000 non-null   object
#  9   incident_type                1000 non-null   object
#  10  collision_type               1000 non-null   object
#  11  incident_severity            1000 non-null   object
#  12  incident_city                1000 non-null   object
# ...

# %% [markdown]
# ### LOAD TOTAL COLUMNS

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_annual_premium', 'insured_sex',
#        'insured_occupation', 'incident_date', 'incident_type',
#        'collision_type', 'incident_severity', 'incident_city',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'witnesses', 'police_report_available',
#        'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
#        'auto_make', 'fraud_reported'],
#       dtype='object')

# %% [markdown]
# ### LOAD DATA TYPES

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_annual_premium          float64
# insured_sex                     object
# insured_occupation              object
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# incident_city                   object
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# property_damage                 object
# witnesses                        int64
# police_report_available         object
# total_claim_amount               int64
# injury_claim                     int64
# property_claim                   int64
# vehicle_claim                    int64
# auto_make                       object
# fraud_reported                   int64
# dtype: object

# %% [markdown]
# ### LOAD HEAD

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#    policy_annual_premium insured_sex insured_occupation incident_date  \
# 0                1406.91        MALE       craft-repair    25-01-2015
# 1                1197.22        MALE  machine-op-inspct    21-01-2015
# 2                1413.14      FEMALE              sales    22-02-2015
# 3                1415.74      FEMALE       armed-forces    10-01-2015
# 4                1583.91        MALE              sales    17-02-2015
#
#               incident_type  ... number_of_vehicles_involved property_damage  \
# ...

# %% [markdown]
# ### LOAD TAIL

# %%
df.tail()
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#      policy_annual_premium insured_sex insured_occupation incident_date  \
# 995                1310.80      FEMALE       craft-repair    22-02-2015
# 996                1436.79      FEMALE     prof-specialty    24-01-2015
# 997                1383.49      FEMALE       armed-forces    23-01-2015
# 998                1356.92        MALE  handlers-cleaners    26-02-2015
# 999                 766.19      FEMALE              sales    26-02-2015
#
#                 incident_type  ... number_of_vehicles_involved  \
# ...

# %% [markdown]
# ### LOAD UNIQUE VALUES

# %%
df.nunique()
# Out:
# months_as_customer              391
# age                              46
# policy_number                  1000
# policy_bind_date                951
# policy_state                      3
# policy_annual_premium           991
# insured_sex                       2
# insured_occupation               14
# incident_date                    60
# incident_type                     4
# collision_type                    4
# incident_severity                 4
# incident_city                     7
# incident_hour_of_the_day         24
# number_of_vehicles_involved       4
# property_damage                   3
# witnesses                         4
# police_report_available           3
# total_claim_amount              763
# injury_claim                    638
# property_claim                  626
# vehicle_claim                   726
# auto_make                        14
# fraud_reported                    2
# dtype: int64

# %% [markdown]
# ### SUM OF NULL VALUES OF EACH COLUMNS

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# #### Replace categorical data Y and N into numeric form

# %%
df['fraud_reported'] = df['fraud_reported'].replace(('Y','N'),(0,1))

# %%
plt.figure(figsize = (25, 20))
plotnumber = 1

for col in df.columns:
    if plotnumber <= 24:
        ax = plt.subplot(5, 5, plotnumber)
        sns.histplot(df[col])
        plt.xlabel(col, fontsize = 15)
        
    plotnumber += 1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### CORRELATION OF EACH COLUMN

# %%
print(df.corr(numeric_only=True))
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.922098       0.057555
# age                                    0.922098  1.000000       0.059413
# policy_number                          0.057555  0.059413       1.000000
# policy_annual_premium                  0.005018  0.014404       0.022566
# incident_hour_of_the_day               0.070639  0.087161       0.000113
# number_of_vehicles_involved            0.014736  0.022102       0.013432
# witnesses                              0.058383  0.052359      -0.012661
# total_claim_amount                     0.062108  0.069863      -0.018009
# injury_claim                           0.065329  0.075522      -0.008762
# property_claim                         0.034940  0.060898      -0.010678
# vehicle_claim                          0.061013  0.062588      -0.020184
# fraud_reported                         0.020544  0.012143      -0.029443
#
# ...

# %% [markdown]
# #### HEAT MAPPING OF CORRELATED DATA

# %%
a=sns.heatmap(df.corr(numeric_only=True))
a
# Out:
# <Axes: >

# %% [markdown]
# ### MEAN OF EACH COLUMN

# %%
df.mean(numeric_only=True)
# Out:
# months_as_customer                203.95400
# age                                38.94800
# policy_number                  546238.64800
# policy_annual_premium            1256.40615
# incident_hour_of_the_day           11.64400
# number_of_vehicles_involved         1.83900
# witnesses                           1.48700
# total_claim_amount              52761.94000
# injury_claim                     7433.42000
# property_claim                   7399.57000
# vehicle_claim                   37928.95000
# fraud_reported                      0.24700
# dtype: float64

# %% [markdown]
# ### MEDIAN VALUE OF EACH COLUMN

# %%
df.median(numeric_only=True)
# Out:
# months_as_customer                199.5
# age                                38.0
# policy_number                  533135.0
# policy_annual_premium            1257.2
# incident_hour_of_the_day           12.0
# number_of_vehicles_involved         1.0
# witnesses                           1.0
# total_claim_amount              58055.0
# injury_claim                     6775.0
# property_claim                   6750.0
# vehicle_claim                   42100.0
# fraud_reported                      0.0
# dtype: float64

# %% [markdown]
# ### MODE VALUE OF EACH COLUMN

# %%
df.mode(numeric_only=True)
# Out:
#      months_as_customer   age  policy_number  policy_annual_premium  \
# 0                 194.0  43.0         100804                1073.83
# 1                   NaN   NaN         101421                1074.07
# 2                   NaN   NaN         104594                1215.36
# 3                   NaN   NaN         106186                1281.25
# 4                   NaN   NaN         106873                1362.87
# ..                  ...   ...            ...                    ...
# 995                 NaN   NaN         996253                    NaN
# 996                 NaN   NaN         996850                    NaN
# 997                 NaN   NaN         998192                    NaN
# 998                 NaN   NaN         998865                    NaN
# 999                 NaN   NaN         999435                    NaN
#
#      incident_hour_of_the_day  number_of_vehicles_involved  witnesses  \
# 0                        17.0                          1.0        1.0
# ...

# %% [markdown]
# ### STANDARD DEVIATION OF EACH COLUMN

# %%
df.std(numeric_only=True)
# Out:
# months_as_customer                115.113174
# age                                 9.140287
# policy_number                  257063.005276
# policy_annual_premium             244.167395
# incident_hour_of_the_day            6.951373
# number_of_vehicles_involved         1.018880
# witnesses                           1.111335
# total_claim_amount              26401.533190
# injury_claim                     4880.951853
# property_claim                   4824.726179
# vehicle_claim                   18886.252893
# fraud_reported                      0.431483
# dtype: float64

# %% [markdown]
# ### DUPLICATED VALUES

# %%
df.duplicated().sum()
# Out:
# 0

# %%
(df.isnull().sum()/(len(df)))*100
# Out:
# months_as_customer             0.0
# age                            0.0
# policy_number                  0.0
# policy_bind_date               0.0
# policy_state                   0.0
# policy_annual_premium          0.0
# insured_sex                    0.0
# insured_occupation             0.0
# incident_date                  0.0
# incident_type                  0.0
# collision_type                 0.0
# incident_severity              0.0
# incident_city                  0.0
# incident_hour_of_the_day       0.0
# number_of_vehicles_involved    0.0
# property_damage                0.0
# witnesses                      0.0
# police_report_available        0.0
# total_claim_amount             0.0
# injury_claim                   0.0
# property_claim                 0.0
# vehicle_claim                  0.0
# auto_make                      0.0
# fraud_reported                 0.0
# dtype: float64

# %% [markdown]
# #### COUNT VALUES BY COLUMN AGE

# %%
df['age'].value_counts()
# Out:
# age
# 43    49
# 39    48
# 41    45
# 34    44
# 38    42
# 30    42
# 31    42
# 37    41
# 33    39
# 40    38
# 32    38
# 29    35
# 46    33
# 42    32
# 35    32
# 36    32
# 44    32
# 28    30
# 26    26
# 45    26
# 48    25
# 47    24
# 27    24
# 57    16
# 25    14
# 55    14
# 49    14
# 53    13
# 50    13
# 24    10
# 54    10
# 61    10
# 51     9
# 60     9
# 58     8
# 56     8
# 23     7
# 21     6
# 59     5
# 62     4
# 52     4
# 64     2
# 63     2
# 19     1
# 20     1
# 22     1
# Name: count, dtype: int64

# %% [markdown]
# ### SUM OF EACH COLUMN CONTAINING NUMERIC VALUE ONLY

# %%
df.sum(numeric_only=True)
# Out:
# months_as_customer             2.039540e+05
# age                            3.894800e+04
# policy_number                  5.462386e+08
# policy_annual_premium          1.256406e+06
# incident_hour_of_the_day       1.164400e+04
# number_of_vehicles_involved    1.839000e+03
# witnesses                      1.487000e+03
# total_claim_amount             5.276194e+07
# injury_claim                   7.433420e+06
# property_claim                 7.399570e+06
# vehicle_claim                  3.792895e+07
# fraud_reported                 2.470000e+02
# dtype: float64

# %% [markdown]
# ### COUNT TOTAL NUMBER OF VALUES OF EACH COLUMN

# %%
df.count()
# Out:
# months_as_customer             1000
# age                            1000
# policy_number                  1000
# policy_bind_date               1000
# policy_state                   1000
# policy_annual_premium          1000
# insured_sex                    1000
# insured_occupation             1000
# incident_date                  1000
# incident_type                  1000
# collision_type                 1000
# incident_severity              1000
# incident_city                  1000
# incident_hour_of_the_day       1000
# number_of_vehicles_involved    1000
# property_damage                1000
# witnesses                      1000
# police_report_available        1000
# total_claim_amount             1000
# injury_claim                   1000
# property_claim                 1000
# vehicle_claim                  1000
# auto_make                      1000
# fraud_reported                 1000
# dtype: int64

# %% [markdown]
# #### DIFFERENCE BETWEEN POLICY STARTED DATE AND DATE OF INCIDENT HAPPENED

# %%
df['difference_period'] = pd.to_datetime(df['incident_date'],dayfirst=True) - pd.to_datetime(df['policy_bind_date'], dayfirst=True)
print(df['difference_period'])
# Out:
# 0      100 days
# 1     3130 days
# 2     5282 days
# 3     8996 days
# 4      256 days
#          ...
# 995   8622 days
# 996    384 days
# 997   4358 days
# 998   1196 days
# 999   6681 days
# Name: difference_period, Length: 1000, dtype: timedelta64[ns]

# %% [markdown]
# ##### Output where total amount claimed on insurance is greater than 50000 and claimed amount on injury occured less than or equal to 2000

# %%
df[df['total_claim_amount']>50000 &(df['injury_claim']<=2000)]
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#      policy_annual_premium insured_sex insured_occupation incident_date  \
# ...

# %% [markdown]
# ##### Output where fraud reported is no and total claim amount less than 50000 or permium paid on insurance policy less than 1500

# %%
df1= df[df['fraud_reported']==1 &( df['total_claim_amount']< 50000) | (df['policy_annual_premium'] <1500 )]
df1
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 3                   256   41         227811       25-05-1990           IL
# 5                   256   39         104594       12-10-2006           OH
# 14                  180   38         644081       28-12-1998           OH
# ..                  ...  ...            ...              ...          ...
# 984                 163   36         974522       27-01-2000           IN
# 985                  29   32         669809       05-04-2002           OH
# 986                 232   42         182953       30-04-2013           IN
# 987                 235   39         836349       01-05-2013           IL
# 988                 295   46         591269       09-01-1999           IN
#
#      policy_annual_premium insured_sex insured_occupation incident_date  \
# ...

# %% [markdown]
# ##### SORTED VALUE OF DIFFERENCE PERIOD IN DESCENDING ORDER

# %%
df['difference_period'].sort_values( ascending=False)
# Out:
# 46    9172 days
# 7     9155 days
# 857   9133 days
# 330   9129 days
# 278   9124 days
#          ...
# 673     46 days
# 209     35 days
# 18      22 days
# 775      6 days
# 578    -20 days
# Name: difference_period, Length: 1000, dtype: timedelta64[ns]

# %%
df30 = df.head(30)

# %% [markdown]
# #### DENSITY PLOTING OF FRAUD REPORTED AS COMPARED WITH TOTAL CLAIM AMOUNT

# %%
fraud_reported = df30['fraud_reported'].value_counts()
fraud_reported
df30.plot.density(x='fraud_reported', y='total_claim_amount',bw_method='scott')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# #### Count how many are reported fraud and how many are not
# ##### The output showing 0 is fraud reported whereas 1 implicits not fraud reported

# %%
fraud_reported = df['fraud_reported'].value_counts()
fraud_reported
# Out:
# fraud_reported
# 0    753
# 1    247
# Name: count, dtype: int64

# %% [markdown]
# ### HISPLOT ON RELATION BETWEEN THE SEVERITY OF ACCIDENT AND FRAUD CLAIM OR NOT

# %%
sns.histplot(df,x='incident_severity',kde=True, palette = 'rocket',hue='fraud_reported')
plt.show()

# %% [markdown]
# #### Visualising using regplot comparing Fraud detected based on the policy holders age

# %%
policyAge = df.groupby('age')['fraud_reported'].sum()
plt.figure(figsize=(20,5))
plt.title("Policy Holder's Age Vs Frauds detected")

ax = sns.regplot(x=policyAge.index,y=policyAge.values,color='black')

# %% [markdown]
# ### PIVOT TABLE

# %%
result= df.pivot(index= 'policy_number', columns='incident_type', values=['incident_city','total_claim_amount']) 
result
# Out:
#                         incident_city                                      \
# incident_type Multi-vehicle Collision Parked Car Single Vehicle Collision
# policy_number
# 100804                      Northbend        NaN                      NaN
# 101421                      Arlington        NaN                      NaN
# 104594                      Arlington        NaN                      NaN
# 106186                    Springfield        NaN                      NaN
# 106873                            NaN        NaN              Springfield
# ...                               ...        ...                      ...
# 996253                      Riverwood        NaN                      NaN
# 996850                            NaN        NaN                Arlington
# 998192                      Riverwood        NaN                      NaN
# 998865                            NaN        NaN                Northbend
# ...

# %%
pivot = pd.pivot_table(
    data=df,
    index='incident_city', aggfunc ='mean',values='total_claim_amount'
)

print(pivot)
# Out:
#                total_claim_amount
# incident_city
# Arlington            48488.486842
# Columbus             54509.597315
# Hillsdale            52982.198582
# Northbend            53879.931034
# Northbrook           51314.344262
# Riverwood            53619.850746
# Springfield          54402.993631

# %% [markdown]
# ### GROUPBY

# %%
test = df.groupby(['insured_sex','collision_type'])
test.describe()
# Out:
#                             months_as_customer                               \
#                                          count        mean         std  min
# insured_sex collision_type
# FEMALE      ?                             92.0  189.271739   98.483903  3.0
#             Front Collision              133.0  219.812030  119.507585  3.0
#             Rear Collision               162.0  190.691358  110.844488  1.0
#             Side Collision               150.0  189.920000  113.949625  1.0
# MALE        ?                             86.0  196.906977  117.277813  4.0
#             Front Collision              121.0  223.322314  124.293551  7.0
#             Rear Collision               130.0  213.907692  119.006836  0.0
#             Side Collision               126.0  207.634921  110.692916  1.0
#
#                                                              age             \
#                                 25%    50%     75%    max  count       mean
# ...

# %% [markdown]
# #### BOXPLOT OF POLICY ANNUAL PREMIUM COLUMN BASED ON GENDER OF POLICY HOLDER

# %%
colors = ["grey", "pink", "skyblue"]
sns.boxplot(
    x='policy_annual_premium',
    data=df,
    palette=colors,hue='policy_state'
)
# Out:
# <Axes: xlabel='policy_annual_premium'>

# %% [markdown]
# ### SCATTER PLOT INCIDENT HOUR OF THE DAY RELATED TO NUMBER OF VEHICLES INVOLVED

# %% [markdown]
# To check is there any difference accidents in specific period of time

# %%
plt.scatter(df['incident_hour_of_the_day'],df['number_of_vehicles_involved'], color='g')
plt.title("Incident_hour")
plt.show()

# %% [markdown]
# #### DISPLOT OF COLLISION TYPE VS TOTAL AMOUNT CLAIMED ON VEHICLE

# %%
plt.figure(figsize=(6,3.2),dpi=150)
plt.rc('xtick', labelsize=6)
plt.rc('ytick', labelsize=8)
sns.displot([df['collision_type'],df['vehicle_claim']],palette= 'Paired_r')
plt.title('collision type vs Vehicle Claim', fontsize = 20)
plt.show()

# %%
fraud_rate = df['fraud_reported'].mean() * 100
print(f"Fraudulent claims: {fraud_rate:.2f}%")
# Out:
# Fraudulent claims: 24.70%

# %% [markdown]
# #### COMPARE  CLAIM DISTRIBUTIONS FOR FRAUDULENT AND NON-FRAUDULENT CLAIMS

# %%
df[df['fraud_reported'] == True]['total_claim_amount'].hist(alpha=0.5, label='Fraudulent')
df[df['fraud_reported'] == False]['total_claim_amount'].hist(alpha=0.5, label='Non-fraudulent')
plt.legend()

# %% [markdown]
# ##### VIOLINPLOT  SHOWING DATA BASED ON PERCENTAGE OF FRAUDULENT CLAIMS BY POLICY DURATION(DIFFERENCE BETWEEN POLICY STARTED DATE AND DATE OF INCIDENT HAPPENED)

# %%
plt.figure(figsize=(12, 6))
adata=df.groupby("difference_period")["fraud_reported"].mean()
sns.violinplot(df,x=adata,color='brown',inner="stick",linecolor="k")
plt.title("Percentage of Fraudulent Claims by Policy Duration")
plt.xlabel("difference_period")
plt.ylabel("Proportion of Fraudulent Claims")
plt.show()

# %% [markdown]
# #### PIE CHART PRESENTATION OF AUTO MAKER OF VEHICLE AND TOTAL AMOUNT CLAIMED ON VEHCLE FOR THE INCIDENT HAPPENED

# %%
df.groupby(['auto_make']).sum().plot( kind='pie', y='vehicle_claim',autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### CONCLUSION OF EXPLORATARY DATA ANALYSIS

# %% [markdown]
# ##### Based on the initial exploration of the data, it appears valuable insights can be gained from analyzing the relationship between factors like months as customer , age, policy annual premium, incident type, incident severity, and total claim amount with the target variable fraud reported. Additionally, investigating potential patterns in categorical features like  incident city, and auto make might prove useful in identifying fraudulent claims. Further exploration through visualizations and statistical tests is recommended to confirm these initial observations and uncover deeper connections within the data.
